# %%
# !nvidia-smi
# Out:
# Mon Jun 16 09:02:02 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/SKRIPSI
# Out:
# /content/drive/MyDrive/SKRIPSI

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.105 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 34.9/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
model = YOLO('/content/drive/MyDrive/SKRIPSI/detect/TRAIN-YAML/YOLOv8s-yaml/weights/best.pt')  # Ganti dengan path ke model kamu

# Path ke gambar uji
image_path = '/content/drive/MyDrive/SKRIPSI/cobatest.jpg'

# Prediksi
results = model(image_path)

# Menampilkan hasil prediksi
results[0].show()  # Membuka jendela gambar
results[0].save(filename='output.jpg')  # Menyimpan hasil ke file
# Out:
# image 1/1 /content/drive/MyDrive/SKRIPSI/cobatest.jpg: 640x640 1 terlalu_matang, 4 matangs, 1 setengah_matang, 3 mentahs, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# 'output.jpg'

# %%
model = YOLO('/content/drive/MyDrive/SKRIPSI/detect/TRAIN-YAML/YOLOv8s+ECA/weights/best.pt')  # Ganti dengan path ke model kamu

# Path ke gambar uji
image_path = '/content/drive/MyDrive/SKRIPSI/cobatest.jpg'

# Prediksi
results = model(image_path)

# Menampilkan hasil prediksi
results[0].show()  # Membuka jendela gambar
results[0].save(filename='output.jpg')  # Menyimpan hasil ke file
# Out:
# image 1/1 /content/drive/MyDrive/SKRIPSI/cobatest.jpg: 640x640 2 terlalu_matangs, 4 matangs, 1 setengah_matang, 6 mentahs, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# 'output.jpg'

# %%
model = YOLO('/content/drive/MyDrive/SKRIPSI/detect/TRAIN-YAML/YOLOv8s+ConvNeXtV2/weights/best.pt')  # Ganti dengan path ke model kamu

# Path ke gambar uji
image_path = '/content/drive/MyDrive/SKRIPSI/cobatest.jpg'

# Prediksi
results = model(image_path)

# Menampilkan hasil prediksi
results[0].show()  # Membuka jendela gambar
results[0].save(filename='output.jpg')  # Menyimpan hasil ke file
# Out:
# image 1/1 /content/drive/MyDrive/SKRIPSI/cobatest.jpg: 640x640 2 terlalu_matangs, 6 matangs, 7 mentahs, 21.5ms
# Speed: 4.1ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# 'output.jpg'

# %%
model = YOLO('/content/drive/MyDrive/SKRIPSI/detect/TRAIN-YAML/YOLOv8s+ECA+ConvNeXtV2/weights/best.pt')  # Ganti dengan path ke model kamu

# Path ke gambar uji
image_path = '/content/drive/MyDrive/SKRIPSI/cobatest.jpg'

# Prediksi
results = model(image_path)

# Menampilkan hasil prediksi
results[0].show()  # Membuka jendela gambar
results[0].save(filename='output.jpg')  # Menyimpan hasil ke file
# Out:
# image 1/1 /content/drive/MyDrive/SKRIPSI/cobatest.jpg: 640x640 1 terlalu_matang, 5 matangs, 1 setengah_matang, 5 mentahs, 22.9ms
# Speed: 3.3ms preprocess, 22.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# 'output.jpg'
